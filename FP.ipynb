# %% [markdown]
# # Final Project Statistika Probabilitas

# %% [markdown]
# ## Kelompok 6

# %% [markdown]
# 1. Afriezal
# 2. Rido
# 3. Rayhan

# %% [markdown]
# ### Data Tingkat Pengangguran di Indonesia periode 2006 - 2022

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('Data Training-1.csv')

# %% [markdown]
# ## Dataset

# %%
#dataset
df
# Out:
#     Periode     Bulan  Tidak/belum pernah sekolah  Tidak/belum tamat SD  \
# 0      2006  Februari                      234465                614960
# 1      2006   Agustus                      170666                611254
# 2      2007  Februari                      145750                520316
# 3      2007   Agustus                       94301                438519
# 4      2008  Februari                       79764                448431
# 5      2008   Agustus                      103206                443832
# 6      2009  Februari                       60347                415955
# 7      2009   Agustus                       90471                547430
# 8      2010  Februari                       59066                547164
# 9      2010   Agustus                      157586                600221
# 10     2011  Februari                       93956                559661
# 11     2011   Agustus                      205388                737610
# ...

# %% [markdown]
# ### Info Dataset

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Periode                     35 non-null     int64
#  1   Bulan                       35 non-null     object
#  2   Tidak/belum pernah sekolah  35 non-null     int64
#  3   Tidak/belum tamat SD        35 non-null     int64
#  4   SD                          35 non-null     int64
#  5   SLTP                        35 non-null     int64
#  6   SLTA Umum/SMU               35 non-null     int64
#  7   SLTA Kejuruan/SMK           35 non-null     int64
#  8   Akademi/Diploma             35 non-null     int64
#  9   Universitas                 35 non-null     int64
#  10  Total                       35 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 3.1+ KB
# None

# %% [markdown]
# ### EDA

# %%
cols_pendidikan = ['Tidak/belum pernah sekolah', 'Tidak/belum tamat SD', 'SD', 
                   'SLTP', 'SLTA Umum/SMU', 'SLTA Kejuruan/SMK', 
                   'Akademi/Diploma', 'Universitas']

# %% [markdown]
# ### Tren Pengagguran per Tahun

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Periode', y='Total', hue='Bulan', marker='o')
plt.title('Tren Jumlah Total per Tahun (Februari vs Agustus)')
plt.ylabel('Jumlah Orang Pengangguran')
plt.show()

# %% [markdown]
# ### Rata-Rata Pengangguran Sesuai Tingkat Pendidkan

# %%
mean_values = df[cols_pendidikan].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=mean_values.values, y=mean_values.index, hue=mean_values.index, palette='viridis',legend=False)
plt.title('Rata-rata Jumlah per Tingkat Pendidikan')
plt.xlabel('Rata-rata Jumlah')
plt.ylabel('Pendidikan')
plt.show()

# %% [markdown]
# ### Distribusi

# %%
target_col = 'Universitas'

plt.figure(figsize=(10, 5))
sns.histplot(df[target_col], kde=True, color='purple')
plt.title(f'Distribusi Data: {target_col}')
plt.show()

# %%
target_col = 'Akademi/Diploma'

plt.figure(figsize=(10, 5))
sns.histplot(df[target_col], kde=True, color='red')
plt.title(f'Distribusi Data: {target_col}')
plt.show()

# %%
target_col = 'SLTA Umum/SMU'

plt.figure(figsize=(10, 5))
sns.histplot(df[target_col], kde=True, color='blue')
plt.title(f'Distribusi Data: {target_col}')
plt.show()

# %%
target_col = 'SLTA Kejuruan/SMK'

plt.figure(figsize=(10, 5))
sns.histplot(df[target_col], kde=True, color='green')
plt.title(f'Distribusi Data: {target_col}')
plt.show()

# %%
target_col = 'SLTP'

plt.figure(figsize=(10, 5))
sns.histplot(df[target_col], kde=True, color='blue')
plt.title(f'Distribusi Data: {target_col}')
plt.show()

# %%
target_col = 'SD'

plt.figure(figsize=(10, 5))
sns.histplot(df[target_col], kde=True, color='pink')
plt.title(f'Distribusi Data: {target_col}')
plt.show()

# %%
target_col = 'Tidak/belum tamat SD'

plt.figure(figsize=(10, 5))
sns.histplot(df[target_col], kde=True, color='black')
plt.title(f'Distribusi Data: {target_col}')
plt.show()

# %%
target_col = 'Tidak/belum pernah sekolah'

plt.figure(figsize=(10, 5))
sns.histplot(df[target_col], kde=True, color='gray')
plt.title(f'Distribusi Data: {target_col}')
plt.show()
